# %%
import re
import bibtexparser
import pandas as pd
import numpy as np

# %% [markdown]
# ### Bibliography

# %%
with open('bds_project_bibliography.bib') as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)
dat = pd.DataFrame(bib_database.entries)

# %%
dat.sort_values('year').reset_index(drop=True)
# Out:
#     year                                                url  \
# 0   1997                                                NaN
# 1   2000                                                NaN
# 2   2001                                                NaN
# 3   2002                         http://mallet.cs.umass.edu
# 4   2002                                                NaN
# 5   2004                                                NaN
# 6   2006                                                NaN
# 7   2008                                                NaN
# 8   2009                                                NaN
# 9   2009                                                NaN
# 10  2009       http://dx.doi.org/10.1016/j.jesp.2009.02.009
# 11  2009                                                NaN
# 12  2010                                                NaN
# 13  2010    http://dx.doi.org/10.1016/j.jpubeco.2009.12.003
# 14  2011                                                NaN
# ...
